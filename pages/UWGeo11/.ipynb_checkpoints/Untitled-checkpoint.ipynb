# %% [raw]
# <!--
# ATLAS NOTEBOOK TEMPLATE
# -->

# %% [raw]
# <!--
# !!! LEAVE THIS CELL UNALTERED !!!
# If things won't render nicely,
# check that the 'type' of this cell
# is set to 'Raw NBConvert'.
# This cell's job is to make
# all the other cells look nice.
# -->
#
# <style>
#     div.cell{
#         float:left;
#         width:50%;
#     }
# </style>

# %% [raw]
# <!--
# GUIDE
#
# The two cells below will become
# two columns in the final HTML view.
# Try to make sure they are the same length
# so everything renders nicely.
#
# To see how the final product will look,
# go to File > Print Preview at the top.
# -->

# %% [raw]
# <!--
# TOP LEFT CELL
# Use this for heading and some introductory text (like a very short abstract).
# -->

# %% [markdown]
# # NAME OF THE CODES YOU'RE USING (e.g. Badlands, Underworld)
# ## Name of the geological process being demonstrated
# ### Names of people involved
#
# For tips on using Markdown - the formatting language that Notebooks use - see this cheat sheet: https://en.support.wordpress.com/markdown-quick-reference/

# %% [raw]
# <!--
# TOP RIGHT CELL
# Use this for a table or image or gif, plus a caption.
# For an example of a table, see below:
# -->

# %% [markdown]
# | **Column A** | **Column B** |
# | --- | --- |
# | This is how | you make a table |
# | using Markdown. | Nice and easy! |
#
# *A caption for the above.*

# %% [raw]
# <!--
# MIDDLE LEFT CELL
# Use this for a table or image or gif, plus a caption.
# For an example of an image embedded from a local source,
# see below.
# -->

# %% [markdown]
# ![cat-sweet-kitty-animals-57416.jpeg](attachment:cat-sweet-kitty-animals-57416.jpeg)
#
# *Often, the easiest way to embed an image or gif is to drag-and-drop it directly into the cell!*

# %% [raw]
# <!--
# MIDDLE RIGHT CELL
# Use this for a table or image or gif, plus a caption.
# For an example of a gif embedded from a remote source,
# see below.
# -->

# %% [markdown]
# ![cat-sweet-kitty-animals-57416.jpeg](cat-sweet-kitty-animals-57416.jpeg)

# %% [markdown]
# ![https://media.giphy.com/media/11i1P8f3LsHp7y/giphy.gif](A gif from GIPHY)
#
# *A caption for the above.*

# %% [raw]
# <!-- vvv BOTTOM LEFT CELL vvv -->

# %% [markdown]
# ---
#
# * Citation 1
# * Citation 2

# %% [raw]
# <!-- vvv BOTTOM RIGHT CELL vvv -->

# %% [markdown]
# ---
